# %%
print(45%8)
# Out:
# 5

# %%
print(int(30/3))
# Out:
# 10

# %%
print(45 % 0.8)
# Out:
# 0.1999999999999975

# %%
#上辺の長さ
upper_base = 10
#下辺の長さ
lower_base = 20
#高さ
height = 5

#台形の面積を計算
area = (upper_base + lower_base)*height/2

# 面積を整数で表示し、単位を付ける
print(f"{int(area)}cm²")
# Out:
# 75cm²
